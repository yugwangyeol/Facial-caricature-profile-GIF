# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 폴더 불러오기
#!git clone https://github.com/facebookresearch/segment-anything.git
# Out:
# Cloning into 'segment-anything'...
# remote: Enumerating objects: 295, done.
# remote: Total 295 (delta 0), reused 0 (delta 0), pack-reused 295 (from 1)
# Receiving objects: 100% (295/295), 18.30 MiB | 37.71 MiB/s, done.
# Resolving deltas: 100% (155/155), done.

# %%
# 경로 이동
# %cd '/content/drive/MyDrive/XAI_ADV/segment-anything'
# Out:
# /content/drive/MyDrive/XAI_ADV/segment-anything

# %%
# 필요 라이브러리 설치
# !pip install opencv-python pycocotools matplotlib onnxruntime onnx
# !pip install -e .
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 98.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 101.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.5 MB/s eta 0:00:00
# ...
# Obtaining file:///content/drive/MyDrive/XAI_ADV/segment-anything
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for segment_anything
# ...

# %%
# !python scripts/amg.py --checkpoint /content/drive/MyDrive/XAI_ADV/segment-anything/sam_vit_h_4b8939.pth --model-type vit_h --input "/content/drive/MyDrive/XAI_ADV/ji.jpg" --output ./
# Out:
# Loading model...
# /content/drive/MyDrive/XAI_ADV/segment-anything/segment_anything/build_sam.py:105: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
pwd
# Out:
# '/content/segment-anything'
